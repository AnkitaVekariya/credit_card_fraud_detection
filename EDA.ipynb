# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, 
            annot=False,  # Set to True to show correlation values
            cmap='coolwarm', 
            fmt=".2f",
            linewidths=0.5)
plt.title("Correlation Heatmap of Features", fontsize=16)
plt.show()

# %%
# Correlation of features with 'Class'
class_corr = correlation_matrix['Class'].sort_values(ascending=False)
# print(class_corr)

# Plot the most correlated features with 'Class'
plt.figure(figsize=(8, 6))
sns.barplot(x=class_corr.index, y=class_corr.values, palette="viridis")
plt.title("Correlation of Features with Fraud (Class)", fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %%
print(class_corr)
print("Min: ",class_corr.min())
print("Max: ",class_corr.max())
# Out:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012323
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326481
# Name: Class, dtype: float64
# Min:  -0.32648106724371595
# Max:  1.0

# %%
class_counts = df['Class'].value_counts()
print("Class Distribution:")
print(class_counts)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(df, x="Class", palette='coolwarm')
plt.title("Class Distribution (0: Legitimate, 1: Fraudulent)", fontsize=14)
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.show()

legitimate_percentage = (class_counts[0] / (class_counts[0] + class_counts[1])) * 100
fraud_percentage = (class_counts[1] / (class_counts[0] + class_counts[1])) * 100
print(f"Percentage of Legitimate Transactions: {legitimate_percentage:.2f}%")
print(f"Percentage of Fraudulent Transactions: {fraud_percentage:.2f}%")
# Out:
# Class Distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# Percentage of Legitimate Transactions: 99.83%
# Percentage of Fraudulent Transactions: 0.17%

# %%
# Plot distributions of 'Time' and 'Amount'
plt.figure(figsize=(12, 6))

# Time
plt.subplot(1, 2, 1)
sns.histplot(df['Time'], bins=50, color='blue', kde=True)
plt.title("Distribution of Time")

# Amount
plt.subplot(1, 2, 2)
sns.histplot(df['Amount'], bins=50, color='green', kde=True)
plt.title("Distribution of Amount")

plt.show()

# %%
# Boxplot for 'Amount'
plt.figure(figsize=(8, 4))
sns.boxplot(df['Amount'])
plt.title("Boxplot of Transaction Amount")
plt.show()

# %%
df[df['Amount'] > 10000]
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 46841    42951.0 -23.712839 -42.172688 -13.320825   9.925019  -13.945538
# 54018    46253.0 -21.780665 -38.305310 -12.122469   9.752791  -12.880794
# 58465    48401.0 -36.802320 -63.344698 -20.645794  16.715537  -20.672064
# 151296   95286.0 -34.549296 -60.464618 -21.340854  16.875344  -19.229075
# 169457  119713.0 -20.924897 -37.943452 -14.060281  10.473005  -10.866639
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
# 284249  172273.0  -9.030538 -11.112584 -16.233798   3.592021  -40.427726
#
#                V6          V7         V8        V9  ...        V21        V22  \
# 46841    5.564891   15.710644  -2.844253 -1.580725  ...   7.921600  -6.320710
# 54018    4.256017   14.785051  -2.818253 -0.667338  ...   7.437478  -5.619439
# 58465    7.694002   24.956587  -4.730111 -2.687312  ...  11.455313 -10.933144
# ...

# %%
# Plot distributions of V1-V28
plt.figure(figsize=(25, 25))
for i, col in enumerate(df.columns[1:29]):
    plt.subplot(7, 4, i+1)
    sns.histplot(df[col], bins=50, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Class'] == 0]['Amount'], bins=50, kde=True, color='blue', label='Non-Fraud')
sns.histplot(df[df['Class'] == 1]['Amount'], bins=50, kde=True, color='red', label='Fraud')
plt.title('Transaction Amount: Fraud vs Non-Fraud')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Convert 'Time' to hours for better interpretation
df['Time_Hours'] = df['Time'] / 3600

# Distribution of 'Time'
plt.figure(figsize=(10, 6))
sns.histplot(df['Time_Hours'], bins=50, kde=True)
plt.title('Distribution of Transaction Time (in Hours)')
plt.xlabel('Time (Hours)')
plt.ylabel('Frequency')
plt.show()

# Fraud distribution over time
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Class'] == 1]['Time_Hours'], bins=50, kde=True, color='red')
plt.title('Fraudulent Transactions Over Time (in Hours)')
plt.xlabel('Time (Hours)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Class'] == 0]['Time_Hours'], bins=50, kde=True, color='blue', label='Non-Fraud')
sns.histplot(df[df['Class'] == 1]['Time_Hours'], bins=50, kde=True, color='red', label='Fraud')
plt.title('Transaction Time: Fraud vs Non-Fraud')
plt.xlabel('Time (Hours)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ##  Key Insights from EDA
#
# - **Class Imbalance**: The dataset is highly imbalanced, with fraud cases making up a tiny fraction of the total transactions.
#
# - **Transaction Amount**: Fraudulent transactions tend to be smaller in amount compared to legitimate ones.
#
# - **Time Distribution**: Fraudulent transactions are spread across time, but there may be specific time periods with higher fraud activity.
#
# - **Correlation**: Some PCA features (e.g., **V14, V12, V10**) show significant **negative correlation** with fraud, while others (e.g., **V2, V4, V11**) show **positive correlation**.
